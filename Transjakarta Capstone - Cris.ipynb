# %% [markdown]
# # Data
# Untuk menjawab pertanyaan di atas, kita akan menganalisa data Transjakarta

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Data Transjakarta memiliki struktur sebagai berikut:
# * transID: Unique transaction id for every transaction
# * payCardID: Customers main identifier. The card customers use as a ticket for entrance and exit.
# * payCardBank: Customers card bank issuer name
# * payCardName: Customers name that is embedded in the card.
# * payCardSex: Customers sex that is embedded in the card
# * payCardBirthDate: Customers birth year
# * corridorID: Corridor ID / Route ID as key for route grouping.
# * corridorName: Corridor Name / Route Name contains Start and Finish for each route.
# * direction: 0 for Go, 1 for Back. Direction of the route.
# * tapInStops: Tap In (entrance) Stops ID for identifying stops name
# * tapInStopsName: Tap In (entrance) Stops Name where customers tap in.
# * tapInStopsLat: Latitude of Tap In Stops
# * tapInStopsLon: Longitude of Tap In Stops
# * stopStartSeq: Sequence of the stops, 1st stop, 2nd stops etc. Related to direction.
# * tapInTime: Time of tap in. Date and time
# * tapOutStops: Tap Out (Exit) Stops ID for identifying stops name
# * tapOutStopsName: Tap out (exit) Stops Name where customers tap out.
# * tapOutStopsLat: Latitude of Tap Out Stops
# * tapOutStopsLon: Longitude of Tap Out Stops
# * stopEndSeq: Sequence of the stops, 1st stop, 2nd stops etc. Related to direction.
# * tapOutTime: Time of tap out. Date and time
# * payAmount: The number of what customers pay. Some are free. Some not.

# %%
df=pd.read_csv('Transjakarta.csv')
display(df.head(),df.tail())
# Out:
#           transID         payCardID payCardBank      payCardName payCardSex  \
# 0  EIIW227B8L34VB   180062659848800      emoney   Bajragin Usada          M
# 1  LGXO740D2N47GZ  4885331907664776         dki     Gandi Widodo          F
# 2  DJWR385V2U57TO  4996225095064169         dki    Emong Wastuti          F
# 3  JTUZ800U7C86EH      639099174703       flazz     Surya Wacana          F
# 4  VMLO535V7F95NJ      570928206772       flazz  Embuh Mardhiyah          M
#
#    payCardBirthDate corridorID                              corridorName  \
# 0              2008          5                     Matraman Baru - Ancol
# 1              1997         6C  Stasiun Tebet - Karet via Patra Kuningan
# 2              1992        R1A                        Pantai Maju - Kota
# 3              1978        11D       Pulo Gebang - Pulo Gadung 2 via PIK
# 4              1982         12                     Tanjung Priok - Pluit
#
# ...

# %% [markdown]
# ## Data Understanding and Cleaning
# Sebelum masuk ke dalam analisis, kita perlu mengenal dataset kita lebih jauh dalam tahapan *data understanding*. Dari proses ini, kita akan tahu anomali-anomali apa saja yang terdapat di dalam dataset kita dan perlu ditangani dalam tahapan *data cleaning*. Setiap penangan anomali yang dilakukan, akan disertai dengan justifikasi langkah yang diambil, baik secara *domain knowledge* maupun secara statistik.
#
# Pertama, mari kita lihat informasi umur dari dataset Transjakarta

# %%
print(f'Jumlah baris dan kolom di dataset df adalah {df.shape}')
df.info()
# Out:
# Jumlah baris dan kolom di dataset df adalah (37900, 22)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37900 entries, 0 to 37899
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transID           37900 non-null  object
#  1   payCardID         37900 non-null  int64
#  2   payCardBank       37900 non-null  object
#  3   payCardName       37900 non-null  object
#  4   payCardSex        37900 non-null  object
#  5   payCardBirthDate  37900 non-null  int64
#  6   corridorID        36643 non-null  object
#  7   corridorName      35970 non-null  object
#  8   direction         37900 non-null  float64
#  9   tapInStops        36687 non-null  object
#  10  tapInStopsName    37900 non-null  object
#  11  tapInStopsLat     37900 non-null  float64
#  12  tapInStopsLon     37900 non-null  float64
#  13  stopStartSeq      37900 non-null  int64
#  14  tapInTime         37900 non-null  object
# ...

# %%
display(df.describe(), df.describe(include='object'))
# Out:
#           payCardID  payCardBirthDate     direction  tapInStopsLat  \
# count  3.790000e+04      37900.000000  37900.000000   37900.000000
# mean   4.250060e+17       1990.089314      0.500633      -6.214838
# std    1.321699e+18         13.051482      0.500006       0.057911
# min    6.040368e+10       1946.000000      0.000000      -6.394973
# 25%    1.800442e+14       1982.000000      0.000000      -6.245863
# 50%    3.507947e+15       1990.000000      1.000000      -6.214587
# 75%    4.699023e+15       2001.000000      1.000000      -6.175528
# max    4.997694e+18       2012.000000      1.000000      -6.089429
#
#        tapInStopsLon  stopStartSeq  tapOutStopsLat  tapOutStopsLon  \
# count   37900.000000  37900.000000    36556.000000    36556.000000
# mean      106.841554     13.572480       -6.214651      106.841233
# std         0.060369     12.237623        0.059022        0.060999
# min       106.614730      0.000000       -6.394973      106.614730
# ...

# %%
pd.set_option('display.max_colwidth', None)
# data uni di tiap kolom
listItem = []
for col in df.columns :
    listItem.append( [col, df[col].nunique(), df[col].unique()])

tabel1Desc = pd.DataFrame(columns=['Column Name', 'Number of Unique', 'Unique Sample'],
                     data=listItem)
tabel1Desc
# Out:
#          Column Name  Number of Unique  \
# 0            transID             37900
# 1          payCardID              2000
# 2        payCardBank                 6
# 3        payCardName              1993
# 4         payCardSex                 2
# 5   payCardBirthDate                67
# 6         corridorID               221
# 7       corridorName               216
# 8          direction                 2
# 9         tapInStops              2570
# 10    tapInStopsName              2602
# 11     tapInStopsLat              2587
# 12     tapInStopsLon              2458
# 13      stopStartSeq                67
# 14         tapInTime             37079
# 15       tapOutStops              2230
# 16   tapOutStopsName              2248
# 17    tapOutStopsLat              2237
# 18    tapOutStopsLon              2139
# 19        stopEndSeq                74
# 20        tapOutTime             35908
# 21         payAmount                 3
#
# ...

# %% [markdown]
# Secara umum, kita bisa melihat bahwa:
# * dataset Transjakarta memiliki 22 kolom dan 37.900 baris
# * kolom `transID` berisikan id unik untuk tiap transaksi, sehingga tidak relevan dalam analisis dan bisa dihapus saja.
# * kolom `payAmount` memiliki range data yang cukup besar, dari 0-20.000. Dengan asumsi terdapat user yang naik Transjakarta dengan gratis,
# * beberapa data kategorik ordinal, bisa dibuatkan kolom baru berdasarkan ranking kategorinya untuk memudahkan analisis (opsional)

# %% [markdown]
# # Missing Value

# %%
# persentase missing value di tiap kolom
df.isna().sum()/df.shape[0]*100
# Out:
# transID             0.000000
# payCardID           0.000000
# payCardBank         0.000000
# payCardName         0.000000
# payCardSex          0.000000
# payCardBirthDate    0.000000
# corridorID          3.316623
# corridorName        5.092348
# direction           0.000000
# tapInStops          3.200528
# tapInStopsName      0.000000
# tapInStopsLat       0.000000
# tapInStopsLon       0.000000
# stopStartSeq        0.000000
# tapInTime           0.000000
# tapOutStops         6.039578
# tapOutStopsName     3.546174
# tapOutStopsLat      3.546174
# tapOutStopsLon      3.546174
# stopEndSeq          3.546174
# tapOutTime          3.546174
# payAmount           2.656992
# dtype: float64

# %%
# Sebaran missing value di dalam data
plt.figure(figsize=(10,10))
sns.heatmap(df[['corridorID','corridorName','tapOutStops','tapOutStopsName','tapOutTime','tapOutStopsLat','tapOutStopsLon','stopEndSeq','tapInStops','payAmount']].isna())
# Out:
# <Axes: >

# %% [markdown]
# Secara garis besar:
# * *missing value* di yang terdapat pada data tidaklah begitu besar. Kolom `tapOutStops` memiliki *missing value* terbesar dengan persentase `6.03%`
# * *missing value* di kolom `tapOutStops`, `tapOutStopsName`, `tapOutTime`, `tapOutStopsLat`, `tapOutStopsLon`, dan `stopEndSeq` memiliki sebaran yang terlihat berkaitan, jika data di `tapOutStops` kosong, maka kemungkinan besar data di kolom `tapOutStopsName`, `tapOutTime`, `tapOutStopsLat`, `tapOutStopsLon`, dan `stopEndSeq` juga kosong.
# * *missing value* yang berkaitan tidak memberikan informasi tambahan. Karena seharusnya kalau tapIn akan tapOut
#
# Cara untuk menangani *missing value*:
# * pertama, menghapus baris/kolom yang berisi *missing value*. Cara ini mungkin akan dilakukan karena jumlah *missing value* kecil.

# %% [markdown]
# # Menghapus *missing value*

# %%
# Menghapus baris dengan missing values
data_cleaned = df.dropna()

# Menampilkan ukuran dataframe sebelum dan sesudah penghapusan
print("Ukuran data sebelum pembersihan:", df.shape)
print("Ukuran data setelah pembersihan:", data_cleaned.shape)
# Out:
# Ukuran data sebelum pembersihan: (37900, 22)
# Ukuran data setelah pembersihan: (31730, 22)

# %% [markdown]
# # Cek Distribusi Data

# %%
# Menampilkan statistik deskriptif untuk setiap kolom
print(data_cleaned.describe(include='all'))
# Out:
#                transID     payCardID payCardBank  payCardName payCardSex  \
# count            31730  3.173000e+04       31730        31730      31730
# unique           31730           NaN           6         1917          2
# top     EIIW227B8L34VB           NaN         dki  Suci Wacana          F
# freq                 1           NaN       15702           71      16939
# mean               NaN  4.206483e+17         NaN          NaN        NaN
# std                NaN  1.316424e+18         NaN          NaN        NaN
# min                NaN  6.040368e+10         NaN          NaN        NaN
# 25%                NaN  1.800443e+14         NaN          NaN        NaN
# 50%                NaN  3.507251e+15         NaN          NaN        NaN
# 75%                NaN  4.684821e+15         NaN          NaN        NaN
# max                NaN  4.997694e+18         NaN          NaN        NaN
#
#         payCardBirthDate corridorID          corridorName     direction  \
# ...

# %%
# Histogram untuk kolom `payAmount`
plt.figure(figsize=(10,6))
sns.histplot(data_cleaned['payAmount'], bins=30, kde=True)
plt.title('Distribusi Jumlah Pembayaran')
plt.show()

# Boxplot untuk kolom `payAmount`
plt.figure(figsize=(10,6))
sns.boxplot(data_cleaned['payAmount'])
plt.title('Boxplot Jumlah Pembayaran')
plt.show()

# Bar chart untuk kolom `payCardBank`
plt.figure(figsize=(12,7))
sns.countplot(y=data_cleaned['payCardBank'], order=data_cleaned['payCardBank'].value_counts().index)
plt.title('Distribusi Transaksi Berdasarkan Bank')
plt.show()

# %% [markdown]
# Diagram batang ini menunjukkan jumlah transaksi untuk setiap bank. Terlihat beberapa bank mendominasi transaksi, sementara yang lain memiliki volume yang lebih sedikit. Ini bisa menunjukkan popularitas tertentu dari bank-bank tersebut atau kesepakatan kemitraan dengan Transjakarta.

# %%
# Membuat heatmap korelasi dengan penentuan eksplisit numeric_only=True
plt.figure(figsize=(12,8))
sns.heatmap(data_cleaned.corr(numeric_only=True), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Heatmap Korelasi')
plt.show()

# %% [markdown]
# Heatmap ini menunjukkan korelasi antara variabel numerik. Terlihat ada beberapa variabel dengan korelasi positif yang kuat, tetapi kebanyakan variabel tampak tidak terlalu berkorelasi satu sama lain. Ini menunjukkan bahwa kebanyakan variabel beroperasi secara independen satu sama lain.

# %%
# Scatter plot antara `stopStartSeq` dan `stopEndSeq`
plt.figure(figsize=(10,6))
sns.scatterplot(x=data_cleaned['stopStartSeq'], y=data_cleaned['stopEndSeq'])
plt.title('Hubungan antara stopStartSeq dan stopEndSeq')
plt.show()

# %% [markdown]
# Scatter plot ini menunjukkan hubungan antara stopStartSeq dan stopEndSeq. Terlihat ada pola linier di mana stopEndSeq meningkat seiring dengan stopStartSeq, yang masuk akal karena semakin jauh penumpang mulai perjalanan, semakin jauh juga mereka cenderung berakhir.

# %%
# Membuat salinan dari data_cleaned
data_cleaned_copy = data_cleaned.copy()

# Memastikan bahwa kolom 'payCardSex' adalah tipe data kategorikal
data_cleaned_copy['payCardSex'] = data_cleaned_copy['payCardSex'].astype('category')

# Membuat visualisasi
plt.figure(figsize=(7,5))
sns.countplot(x=data_cleaned_copy['payCardSex'])
plt.title('Distribusi Jenis Kelamin')
plt.show()

# %% [markdown]
# Diagram batang ini menunjukkan distribusi transaksi berdasarkan jenis kelamin. Terlihat ada lebih banyak transaksi yang dilakukan oleh laki-laki dibandingkan perempuan. Ini bisa menunjukkan bahwa laki-laki lebih cenderung menggunakan Transjakarta dibandingkan perempuan, atau mungkin ada bias dalam cara data dikumpulkan.

# %%
# Visualizing the distribution of transactions by hour side-by-side
plt.figure(figsize=(14,6))
sns.countplot(data=data_cleaned, x='tapInHour', color='skyblue', label='Tap In', order=range(24))
sns.countplot(data=data_cleaned, x='tapOutHour', color='salmon', label='Tap Out', order=range(24))
plt.title('Distribusi Transaksi Berdasarkan Jam')
plt.legend()
plt.show()

# %% [markdown]
# Terima kasih telah menyediakan screenshot grafik tersebut. Berdasarkan gambar yang saya lihat:
#
# Grafik menunjukkan distribusi transaksi Transjakarta berdasarkan jam.
#
# Sumbu X: Mewakili jam dalam sehari, mulai dari 0 (tengah malam) hingga 23 (jam 11 malam).
# Sumbu Y: Mewakili jumlah transaksi.
# Biru Muda (Tap In): Menunjukkan jumlah penumpang yang melakukan tap in (mulai menggunakan layanan) pada jam tertentu.
# Merah Muda (Tap Out): Menunjukkan jumlah penumpang yang melakukan tap out (selesai menggunakan layanan) pada jam tertentu.
#
#
# Interpretasi:
#
# Puncak Aktivitas di Pagi Hari: Ada puncak yang signifikan pada jam 6-7 pagi untuk aktivitas Tap In, yang menunjukkan banyak penumpang yang mulai menggunakan Transjakarta pada jam tersebut. Ini mungkin dikaitkan dengan orang yang berangkat ke tempat kerja atau sekolah.
# Puncak Aktivitas di Sore Hari: Ada puncak lain yang signifikan pada jam 16-18 untuk aktivitas Tap Out, yang menunjukkan banyak penumpang yang selesai menggunakan Transjakarta pada jam tersebut. Ini mungkin dikaitkan dengan orang yang pulang dari tempat kerja atau sekolah.
# Aktivitas Rendah di Malam Hari: Setelah jam 20, aktivitas Tap In dan Tap Out menurun secara signifikan, menunjukkan bahwa ada lebih sedikit penumpang yang menggunakan Transjakarta pada malam hari.
# Kesimpulannya, grafik ini memberikan gambaran tentang pola penggunaan Transjakarta oleh penumpangnya. Pengetahuan tentang jam sibuk ini sangat penting bagi operator Transjakarta untuk memastikan ketersediaan bus yang cukup dan mungkin juga untuk merencanakan strategi harga atau promosi yang sesuai dengan waktu.

# %% [markdown]
# # Analisis Lokasi

# %%
# Top 10 stations with the highest Tap In activity
top_tap_in_stations = data_cleaned['tapInStopsName'].value_counts().head(10)

# Top 10 stations with the highest Tap Out activity
top_tap_out_stations = data_cleaned['tapOutStopsName'].value_counts().head(10)

# Visualizing the top stations
fig, ax = plt.subplots(2, 1, figsize=(15, 12))

# Tap In Stations
sns.barplot(x=top_tap_in_stations.values, y=top_tap_in_stations.index, ax=ax[0], color='skyblue')
ax[0].set_title('10 Stasiun dengan Aktivitas Tap In Tertinggi')
ax[0].set_xlabel('Jumlah Tap In')
ax[0].set_ylabel('Nama Stasiun')

# Tap Out Stations
sns.barplot(x=top_tap_out_stations.values, y=top_tap_out_stations.index, ax=ax[1], color='salmon')
ax[1].set_title('10 Stasiun dengan Aktivitas Tap Out Tertinggi')
ax[1].set_xlabel('Jumlah Tap Out')
ax[1].set_ylabel('Nama Stasiun')

plt.tight_layout()
plt.show()

# %% [markdown]
# Berikut visualisasi dari 10 stasiun dengan aktivitas Tap In dan Tap Out tertinggi:
#
# 1. 10 Stasiun dengan Aktivitas Tap In Tertinggi (Biru Muda)
#
# Grafik ini menunjukkan stasiun mana yang paling sering digunakan oleh penumpang untuk memulai perjalanan mereka menggunakan Transjakarta.
# Anda dapat melihat stasiun mana yang paling ramai berdasarkan jumlah tap in dan membandingkannya dengan stasiun lain.
#
# 2. 10 Stasiun dengan Aktivitas Tap Out Tertinggi (Merah Muda)
#
# Grafik ini menunjukkan stasiun mana yang paling sering digunakan oleh penumpang untuk menyelesaikan perjalanan mereka menggunakan Transjakarta.
# Mirip dengan analisis tap in, Anda dapat melihat stasiun mana yang paling ramai berdasarkan jumlah tap out.
# Kesimpulan:
#
# Mengidentifikasi stasiun mana yang paling ramai dapat membantu dalam perencanaan kapasitas, seperti menambah bus di rute tertentu atau meningkatkan fasilitas di stasiun tersebut.
# Jika ada stasiun yang kurang ramai, mungkin ada potensi untuk mengadakan promosi atau kampanye pemasaran khusus untuk meningkatkan penggunaannya.

# %%
# Extracting birth year from 'payCardBirthDate' column
data_cleaned['birthYear'] = pd.to_datetime(data_cleaned['payCardBirthDate']).dt.year

# Calculating age from birth year
current_year = pd.Timestamp.now().year
data_cleaned['age'] = current_year - data_cleaned['birthYear']

# Plotting age distribution
plt.figure(figsize=(14,6))
sns.histplot(data_cleaned['age'], bins=30, color='mediumseagreen', kde=True)
plt.title('Distribusi Umur Penumpang')
plt.xlabel('Umur')
plt.ylabel('Jumlah Penumpang')
plt.show()

# %%
# Plotting the distribution of transaction costs using the correct column
plt.figure(figsize=(14,6))
sns.histplot(data_cleaned['payAmount'], bins=50, color='mediumpurple', kde=True)
plt.title('Distribusi Biaya Transaksi')
plt.xlabel('Biaya (IDR)')
plt.ylabel('Jumlah Transaksi')
plt.show()

# %% [markdown]
# Berikut adalah visualisasi distribusi biaya transaksi untuk penumpang Transjakarta:
#
# Sumbu X: Biaya transaksi dalam IDR.
# Sumbu Y: Jumlah transaksi.
# Interpretasi:
#
# Mayoritas transaksi memiliki biaya antara IDR 0 hingga IDR 5.000.
# Ada puncak yang signifikan sekitar IDR 2.000, yang mungkin menunjukkan tarif standar atau yang paling umum untuk perjalanan Transjakarta.
# Terdapat beberapa transaksi dengan biaya lebih tinggi, tetapi jumlahnya jauh lebih sedikit dibandingkan dengan biaya yang lebih rendah.
# Kesimpulan:
#
# Sebagian besar penumpang Transjakarta membayar tarif yang relatif rendah, yang menunjukkan bahwa Transjakarta mungkin menawarkan tarif yang kompetitif dan terjangkau.
# Informasi ini dapat digunakan untuk menilai struktur harga saat ini dan membandingkannya dengan biaya operasional, atau untuk merencanakan promosi atau diskon berdasarkan biaya transaksi.

# %% [markdown]
# # Analisis Rute Populer

# %%
# Creating a new column for route combining tapInStopsName and tapOutStopsName
data_cleaned['route'] = data_cleaned['tapInStopsName'] + " - " + data_cleaned['tapOutStopsName']

# Top 10 most popular routes
top_routes = data_cleaned['route'].value_counts().head(10)

# Visualizing the top routes
plt.figure(figsize=(12,8))
sns.barplot(x=top_routes.values, y=top_routes.index, palette='viridis')
plt.title('10 Rute Paling Populer')
plt.xlabel('Jumlah Transaksi')
plt.ylabel('Rute')
plt.show()

# %% [markdown]
# # Analisis Durasi Perjalanan

# %%
# Calculate travel duration
data_cleaned['tapInTime'] = pd.to_datetime(data_cleaned['tapInTime'], errors='coerce')
data_cleaned['tapOutTime'] = pd.to_datetime(data_cleaned['tapOutTime'], errors='coerce')
data_cleaned['duration'] = (data_cleaned['tapOutTime'] - data_cleaned['tapInTime']).dt.total_seconds() / 60  # in minutes

# Visualize the distribution of travel duration
plt.figure(figsize=(14,6))
sns.histplot(data_cleaned['duration'], bins=100, color='lightcoral', kde=True)
plt.title('Distribusi Durasi Perjalanan (dalam menit)')
plt.xlabel('Durasi (menit)')
plt.ylabel('Jumlah Transaksi')
plt.xlim(0, 180)  # limiting to 3 hours for better visualization
plt.show()

# %% [markdown]
# # Analisis Biaya vs Durasi

# %%
# Visualize the relationship between cost and travel duration using the correct column name
plt.figure(figsize=(14,7))
sns.scatterplot(x=data_cleaned['duration'], y=data_cleaned['payAmount'], hue=data_cleaned['payCardSex'], alpha=0.6, palette='viridis')
plt.title('Hubungan Biaya dengan Durasi Perjalanan')
plt.xlabel('Durasi (menit)')
plt.ylabel('Biaya Transaksi (IDR)')
plt.xlim(0, 300)  # Limiting to 5 hours for better visualization
plt.ylim(0, 10000)  # Assuming a reasonable transaction amount
plt.legend(title='Jenis Kelamin')
plt.show()

# %% [markdown]
# # Analisis Transaksi dalam seminggu

# %%
# Extract day of week from the tapInTime column
data_cleaned['day_of_week'] = data_cleaned['tapInTime'].dt.dayofweek

# Mapping day of week to actual day names
days = {0:'Monday', 1:'Tuesday', 2:'Wednesday', 3:'Thursday', 4:'Friday', 5:'Saturday', 6:'Sunday'}
data_cleaned['day_name'] = data_cleaned['day_of_week'].map(days)

# Visualize the distribution of transactions based on day of the week
plt.figure(figsize=(12,6))
sns.countplot(data=data_cleaned, x='day_name', order=days.values(), palette='coolwarm')
plt.title('Distribusi Transaksi berdasarkan Hari dalam Seminggu')
plt.xlabel('Hari')
plt.ylabel('Jumlah Transaksi')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Ada penurunan jumlah transaksi pada akhir pekan, yaitu hari Sabtu dan Minggu. Ini menunjukkan bahwa Transjakarta lebih sering digunakan untuk keperluan sehari-hari seperti bekerja atau bersekolah dibandingkan dengan kegiatan akhir pekan.

# %% [markdown]
# # Analisis Berdasarkan Stasiun

# %%
# Top 10 stations for tap in
top_tapin_stations = data_cleaned['tapInStopsName'].value_counts().head(10)

# Top 10 stations for tap out
top_tapout_stations = data_cleaned['tapOutStopsName'].value_counts().head(10)

plt.figure(figsize=(14,6))
top_tapin_stations.plot(kind='bar', color='skyblue', label='Tap In')
plt.title('10 Stasiun dengan Jumlah Tap In Terbanyak')
plt.xlabel('Nama Stasiun')
plt.ylabel('Jumlah Transaksi')
plt.xticks(rotation=45)
plt.legend()
plt.show()

plt.figure(figsize=(14,6))
top_tapout_stations.plot(kind='bar', color='salmon', label='Tap Out')
plt.title('10 Stasiun dengan Jumlah Tap Out Terbanyak')
plt.xlabel('Nama Stasiun')
plt.ylabel('Jumlah Transaksi')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# # Analisis Berdasarkan Hari

# %%
# Average travel duration based on day of the week
avg_duration_per_day = data_cleaned.groupby('day_name')['duration'].mean().reindex(days.values())

plt.figure(figsize=(14,6))
avg_duration_per_day.plot(kind='line', marker='o', color='green')
plt.title('Rata-Rata Durasi Perjalanan Berdasarkan Hari dalam Seminggu')
plt.xlabel('Hari')
plt.ylabel('Rata-Rata Durasi (menit)')
plt.xticks(rotation=45)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()
